# %%
import pandas as pd

# %%
data = pd.read_csv("new_data.csv")

# %%
data
# Out:
#      Unnamed: 0  order                                               name  \
# 0             1      1                               1',4',6'-3Cl-sucrose
# 1             2      2                                  1',4'-2Cl-sucrose
# 2             4      3                                  1',6'-2Cl-sucrose
# 3             6      4                                      1'-Cl-sucrose
# 4             8      5                          4'-Br-4,1',6'-3Cl-sucrose
# 5            10      6                           4'-F-4,1',6'-3Cl-sucrose
# 6            12      7                             4,1',4',6'-4Br-sucrose
# 7            14      8                             4,1',4',6'-4Cl-sucrose
# 8            16      9                                4,1',4'-3Cl-sucrose
# 9            18     10                                4,1',6'-3Br-sucrose
# 10           20     11                                4,1',6'-3Cl-sucrose
# 11           22     12                                 4,1',6'-3F-sucrose
# ...

# %%
data["smiles"]
# Out:
# 0         ClC1C(O)[C@@](OC1CCl)(OC1OC(CO)C(O)C(O)C1O)CCl
# 1          ClC1C(O)[C@@](OC1CO)(OC1OC(CO)C(O)C(O)C1O)CCl
# 2           ClCC1O[C@](OC2OC(CO)C(O)C(O)C2O)(CCl)C(O)C1O
# 3            ClC[C@]1(OC(CO)C(O)C1O)OC1OC(CO)C(O)C(O)C1O
# 4        BrC1C(O)[C@@](OC1CCl)(OC1OC(CO)C(Cl)C(O)C1O)CCl
# 5         ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(F)C1O)CCl
# 6        BrC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CBr)C(Br)C1O)CBr
# 7        ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(Cl)C1O)CCl
# 8         ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CO)C(Cl)C1O)CCl
# 9         BrC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CBr)C(O)C1O)CBr
# 10        ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(O)C1O)CCl
# 11           FC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CF)C(O)C1O)CF
# 12           IC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CI)C(O)C1O)CI
# 13         ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CO)C(O)C1O)CCl
# 14        ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(Cl)C1O)CO
# 15       ClC1C(O)C(O)C(OC1CCl)O[C@@]1(OC(CCl)C(O)C1O)CCl
# ...

# %%
k = 0
for i in data["smiles"]:
    print i
# Out:
# ClC1C(O)[C@@](OC1CCl)(OC1OC(CO)C(O)C(O)C1O)CCl
# ClC1C(O)[C@@](OC1CO)(OC1OC(CO)C(O)C(O)C1O)CCl
# nan
# ClCC1O[C@](OC2OC(CO)C(O)C(O)C2O)(CCl)C(O)C1O
# nan
# ClC[C@]1(OC(CO)C(O)C1O)OC1OC(CO)C(O)C(O)C1O
# nan
# BrC1C(O)[C@@](OC1CCl)(OC1OC(CO)C(Cl)C(O)C1O)CCl
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(F)C1O)CCl
# nan
# BrC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CBr)C(Br)C1O)CBr
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(Cl)C1O)CCl
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CO)C(Cl)C1O)CCl
# nan
# BrC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CBr)C(O)C1O)CBr
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(O)C1O)CCl
# nan
# FC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CF)C(O)C1O)CF
# nan
# IC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CI)C(O)C1O)CI
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CO)C(O)C1O)CCl
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CCl)C(Cl)C1O)CO
# nan
# ClC1C(O)C(O)C(OC1CCl)O[C@@]1(OC(CCl)C(O)C1O)CCl
# nan
# ClC1C(O)C(O)C(OC1CO)O[C@@]1(OC(CO)C(O)C1O)CO
# nan
# BrC1C(O)[C@@](OC1CBr)(OC1OC(CO)C(F)C(O)C1O)CBr
# ...

# %%
k = 0
for i in data["smiles"]:
    k = k +1
    z = str(k)
    file = open(z + ".smi","w")
    file.write(str(i))
    file.close()
